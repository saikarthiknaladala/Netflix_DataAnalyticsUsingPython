# %% [markdown]
# # NETFLIX

# %% [markdown]
# ###### This dataset contains information about TV shows and Movies available on Netflix till 2021.

# %% [markdown]
# ### Importing the dataset

# %%
import pandas as pd
df = pd.read_csv("Netflix_Data.csv")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ### Finding Duplicate Data

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.shape
# Out:
# (7789, 11)

# %% [markdown]
# ### Removing Duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (7787, 11)

# %% [markdown]
# ### Checking Null Values

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ### Importing seaborn lib for heatmap

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Director'].fillna('Unknown', inplace=True)
df['Release_Date'].fillna(df['Release_Date'].mode()[0], inplace=True)
df['Country'].fillna(df['Country'].mode()[0], inplace=True)
df['Rating'].fillna(df['Rating'].mode()[0], inplace=True)
df['Cast'].fillna('Unknown', inplace=True)

# %% [markdown]
# #### Identifying Director for particular series or Movie

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%            Unknown
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# method-1
df[df['Title'].isin(['Sarkar'])]
# Out:
#      Show_Id Category   Title         Director  \
# 5396   s5396    Movie  Sarkar  A.R. Murugadoss
#
#                                                    Cast        Country  \
# 5396  Vijay, Varalakshmi Sarathkumar, Keerthi Suresh...  United States
#
#        Release_Date Rating Duration  \
# 5396  March 2, 2019  TV-MA  162 min
#
#                                                   Type  \
# 5396  Action & Adventure, Dramas, International Movies
#
#                                             Description
# 5396  A ruthless businessman’s mission to expose ele...

# %%
# method-2
df[df['Title'].str.startswith('Sarkar')]
# Out:
#      Show_Id Category   Title         Director  \
# 5396   s5396    Movie  Sarkar  A.R. Murugadoss
#
#                                                    Cast        Country  \
# 5396  Vijay, Varalakshmi Sarathkumar, Keerthi Suresh...  United States
#
#        Release_Date Rating Duration  \
# 5396  March 2, 2019  TV-MA  162 min
#
#                                                   Type  \
# 5396  Action & Adventure, Dramas, International Movies
#
#                                             Description
# 5396  A ruthless businessman’s mission to expose ele...

# %% [markdown]
# #### Identifying an year with highest number of TV Shows and Movies released

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ### to_datetime

# %%
df['Date'] = pd.to_datetime(df['Release_Date'])

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%            Unknown
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category              category
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date            datetime64[ns]
# dtype: object

# %%
df['Date'].dt.year.value_counts()
# Out:
# 2019    2153
# 2020    2019
# 2018    1685
# 2017    1225
# 2016     443
# 2021     117
# 2015      88
# 2014      25
# 2011      13
# 2013      11
# 2012       3
# 2008       2
# 2009       2
# 2010       1
# Name: Date, dtype: int64

# %%
df['Date'].dt.to_period("M").value_counts()
# Out:
# 2019-11    272
# 2020-01    238
# 2019-12    222
# 2019-10    204
# 2018-10    192
#           ...
# 2008-02      1
# 2012-02      1
# 2012-11      1
# 2013-08      1
# 2008-01      1
# Freq: M, Name: Date, Length: 100, dtype: int64

# %% [markdown]
# ### Bar Graph

# %%
df['Date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Date'].dt.to_period("Y").value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #### Finding Total number of TV shows and Movies in the dataset

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
# Check the data types of the 'Category' column
print(df['Category'].dtype)

# Convert 'Category' to categorical type
df['Category'] = df['Category'].astype('category')

# Verify the change
print(df['Category'].dtype)
# Out:
# object
# category

# %%
#import seaborn as sns
import matplotlib.pyplot as plt


sns.countplot(data=df, x='Category')

plt.show()

# %% [markdown]
# #### Showing movies released in 2015 year

# %%
df['Year'] = df['Date'].dt.year

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%            Unknown
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       Date  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016

# %%
df[((df['Category']=='Movie') & (df['Year']==2015))]
# Out:
#      Show_Id Category                                              Title  \
# 128     s129    Movie                                            6 Years
# 247     s248    Movie                            A Very Murray Christmas
# 316     s317    Movie                                       Advantageous
# 535     s536    Movie                         Anjelah Johnson: Not Fancy
# 551     s552    Movie             Anthony Jeselnik: Thoughts and Prayers
# 648     s649    Movie          Aziz Ansari Live at Madison Square Garden
# 785     s786    Movie                                Beasts of No Nation
# 1013   s1014    Movie                                Bob's Broken Sleigh
# 1352   s1353    Movie                         Chris D'Elia: Incorrigible
# 1357   s1358    Movie                                  Chris Tucker Live
# 1394   s1395    Movie                                             Circle
# 1513   s1514    Movie              Cowspiracy: The Sustainability Secret
# ...

# %% [markdown]
# #### showing all titles of all the TV shows released in India

# %%
df[(df['Category']=='TV Show') & (df['Country']=="India")].Title
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# #### showing Top 5 Directors, who gave highest no.of TV Shows and Movies to Netflix

# %%
df['Director'].value_counts().head()
# Out:
# Unknown                   2388
# Raúl Campos, Jan Suter      18
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Name: Director, dtype: int64

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%            Unknown
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       Date  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016

# %% [markdown]
# #### showing all the records, where category is Movie and Type is comedy or country is USA

# %%
df[(df['Category']=='Movie') & ((df['Type']=='Comedies') | (df['Country']=='United States'))]
# Out:
#      Show_Id Category              Title         Director  \
# 3         s4    Movie                  9      Shane Acker
# 4         s5    Movie                 21   Robert Luketic
# 7         s8    Movie                187   Kevin Reynolds
# 10       s11    Movie               1922     Zak Hilditch
# 14       s15    Movie               3022       John Suits
# ...      ...      ...                ...              ...
# 7773   s7772    Movie               Zion       Floyd Russ
# 7776   s7775    Movie             Zodiac    David Fincher
# 7780   s7779    Movie         Zombieland  Ruben Fleischer
# 7783   s7782    Movie               Zoom     Peter Hewitt
# 7786   s7785    Movie  Zulu Man in Japan          Unknown
#
#                                                    Cast        Country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %% [markdown]
# #### Finding total no.of shows/movies, Tom Cruise was cast

# %%
df.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%  Unknown
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description       Date  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020

# %%
df[(df['Cast']=='Tom Cruise')].value_counts()
# Out:
# Series([], dtype: int64)

# %% [markdown]
# #### Different Ratings defined by Netflix

# %%
df.Rating.nunique()
# Out:
# 14

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y',
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# #### Finding total number of movies got the TV-14 rating, in canada

# %%
df[(df['Category']=='Movie')&(df['Rating']=='TV-14')&(df['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %% [markdown]
# #### Finding TV Shows got the R-Rating, after year 2018

# %%
df[(df["Category"]=="TV Show") & (df['Rating']=='R')& (df['Year']>2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast        Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...  United States
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description       Date  Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019

# %% [markdown]
# #### Finding Maximum duration of TV Show/Movie on Netflix

# %%
df.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
df.Duration.dtypes
# Out:
# dtype('O')

# %%
df[['Minutes','Unit']] = df['Duration'].str.split(" ",expand=True)

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%            Unknown
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date            datetime64[ns]
# Year                     int64
# Minutes                 object
# Unit                    object
# dtype: object

# %%
import pandas as pd
df['Minutes'] = df.Minutes.astype('int64')

# %%
df.Minutes.max()
# Out:
# 312

# %%
df.Minutes.min()
# Out:
# 1

# %%
df.Minutes.mean()
# Out:
# 69.12276871709258

# %% [markdown]
# #### Showing which individual country as highest no.of TV shows

# %%
df_tvshow = df[df['Category']=='TV Show'].Country.value_counts().head(1)

# %%
df_tvshow
# Out:
# United States    982
# Name: Country, dtype: int64

# %% [markdown]
# #### Sort the dataset by year

# %%
df.sort_values('Year').head(10)
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show              Dinner for Five               Unknown
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
# 2962   s2963    Movie  In Defense of a Married Man         Joel Oliansky
# 6847   s6846    Movie         The Ryan White Story         John Herzfeld
# 7151   s7150    Movie           Too Young the Hero            Buzz Kulik
# 2622   s2623    Movie                 Hard Lessons       Eric Laneuville
# 308     s309    Movie     Adam: His Song Continues      Robert Markowitz
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# ...

# %%
df.sort_values(by="Year",ascending=False).head()
# Out:
#      Show_Id Category                                              Title  \
# 4864   s4864    Movie            Pinkfong & Baby Shark's Space Adventure
# 2799   s2800    Movie                                               Hook
# 5955   s5955    Movie                                   Taare Zameen Par
# 366     s367    Movie                                          Al acecho
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
#
#                  Director                                               Cast  \
# 4864        Byeon Hee-sun  Jo Kyoung-i, Kim Seo-yeong, Kim Eun-ah, Jeong ...
# 2799     Steven Spielberg  Dustin Hoffman, Robin Williams, Julia Roberts,...
# 5955           Aamir Khan  Aamir Khan, Darsheel Safary, Tanay Chheda, Tis...
# 366   Francisco D'Eufemia  Rodrigo de la Serna, Belen Blanco, Walter Jako...
# 1355           Chris Rock                                         Chris Rock
#
#             Country      Release_Date Rating Duration  \
# ...

# %% [markdown]
# #### Finding the instance where:
# Category is "Movie" and Type is "Dramas"
# #### or
# Category is "TV Show" and Type is "Kids"

# %%
df[((df["Category"]=="TV Show") & (df['Type']=="Kids' TV"))]
#df[(df["Category"]=='Movie') & (df['Type']=="Dramas")]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats              Unknown
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks              Unknown
# 598     s599  TV Show  Ask the StoryBots              Unknown
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko              Unknown
# 7719   s7718  TV Show                YOM              Unknown
# 7758   s7757  TV Show                 Z4              Unknown
# 7761   s7760  TV Show          Zak Storm              Unknown
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %%
df[((df["Category"]=='Movie') & (df['Type']=="Dramas")) | ((df["Category"]=="TV Show") & (df['Type']=="Kids' TV"))].head(10)
# Out:
#     Show_Id Category                           Title          Director  \
# 4        s5    Movie                              21    Robert Luketic
# 7        s8    Movie                             187    Kevin Reynolds
# 111    s112  TV Show                         44 Cats           Unknown
# 170    s171    Movie                    A Family Man     Mark Williams
# 232    s233    Movie      A Stoning in Fulham County     Larry Elikann
# 276    s277  TV Show                    Abby Hatcher       Kyran Kelly
# 295    s296    Movie              Across Grace Alley     Ralph Macchio
# 308    s309    Movie        Adam: His Song Continues  Robert Markowitz
# 330    s331    Movie                       Aftermath    Elliott Lester
# 334    s335    Movie  Agatha and the Truth of Murder       Terry Loane
#
#                                                   Cast  \
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
